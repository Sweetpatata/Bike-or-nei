# %% [markdown]
# # Forecast API

# %%
import pandas as pd
import numpy as np

import sys
import urllib.parse
import requests

# %%
BASE_URL = "https://weather.lewagon.com"
oslo_lat = 59.919602443955355
oslo_lon = 10.752152108688852
#appid = 'ed4479cb1d5ca4806089385ba8f6d277' - Fred's API key

# %%
def weather_forecast(lat, lon):
    '''Return a 5-day weather forecast for the city, given its latitude and longitude.'''
    url = urllib.parse.urljoin(BASE_URL, "/data/2.5/forecast")
    forecasts = requests.get(url, params={'lat': lat, 'lon': lon, 'units': 'metric'}).json()['list']
    return forecasts

# %%
weather_forecast(oslo_lat, oslo_lon)
# Out:
# [{'dt': 1669809600,
#   'main': {'temp': 2.12,
#    'feels_like': 2.12,
#    'temp_min': 2.1,
#    'temp_max': 2.12,
#    'pressure': 1032,
#    'sea_level': 1032,
#    'grnd_level': 1031,
#    'humidity': 61,
#    'temp_kf': 0.02},
#   'weather': [{'id': 600,
#     'main': 'Snow',
#     'description': 'light snow',
#     'icon': '13d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 0.93, 'deg': 34, 'gust': 1.69},
#   'visibility': 6765,
#   'pop': 0.31,
#   'snow': {'3h': 0.13},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2022-11-30 12:00:00'},
#  {'dt': 1669820400,
#   'main': {'temp': 1.54,
#    'feels_like': 1.54,
#    'temp_min': 1.25,
#    'temp_max': 1.54,
#    'pressure': 1033,
#    'sea_level': 1033,
#    'grnd_level': 1031,
#    'humidity': 80,
#    'temp_kf': 0.29},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 0.9, 'deg': 34, 'gust': 1.2},
# ...

# %%
weather_forecast(oslo_lat, oslo_lon)[0]['main']['temp_min']
weather_forecast(oslo_lat, oslo_lon)[0]['main']['temp_max']
weather_forecast(oslo_lat, oslo_lon)[0]['weather']['icon']
weather_forecast(oslo_lat, oslo_lon)[0]['wind']['speed']

# %%
#weather_forecast(oslo_lat, oslo_lon)

# %%
oslo_weather_5day_forecast = weather_forecast(oslo_lat, oslo_lon)
oslo_weather_forecast_df = pd.DataFrame(oslo_weather_5day_forecast)

# %%
oslo_weather_forecast_df.head()
# Out:
#            dt                                               main  \
# 0  1669809600  {'temp': 2.12, 'feels_like': 2.12, 'temp_min':...
# 1  1669820400  {'temp': 1.54, 'feels_like': 1.54, 'temp_min':...
# 2  1669831200  {'temp': 1.03, 'feels_like': 1.03, 'temp_min':...
# 3  1669842000  {'temp': 1.24, 'feels_like': 1.24, 'temp_min':...
# 4  1669852800  {'temp': 1.45, 'feels_like': 1.45, 'temp_min':...
#
#                                              weather        clouds  \
# 0  [{'id': 600, 'main': 'Snow', 'description': 'l...  {'all': 100}
# 1  [{'id': 804, 'main': 'Clouds', 'description': ...  {'all': 100}
# 2  [{'id': 600, 'main': 'Snow', 'description': 'l...   {'all': 99}
# 3  [{'id': 500, 'main': 'Rain', 'description': 'l...  {'all': 100}
# 4  [{'id': 804, 'main': 'Clouds', 'description': ...  {'all': 100}
#
#                                        wind  visibility   pop          snow  \
# 0  {'speed': 0.93, 'deg': 34, 'gust': 1.69}        6765  0.31  {'3h': 0.13}
# ...

# %%
#oslo_weather_forecast_df.head()['main'][2]
